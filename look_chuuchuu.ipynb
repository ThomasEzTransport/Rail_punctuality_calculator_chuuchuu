# %%
import pandas as pd

# %%
data = pd.read_csv("delay_records_2026-02-26_to_2026-03-04.csv")
# Out:
# C:\Users\TE\AppData\Local\Temp\ipykernel_29316\4016970825.py:1: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("delay_records_2026-02-26_to_2026-03-04.csv")

# %%
data
# Out:
#         agency routeType routeNumber        date deutscheBahnStopId  \
# 0           NS  Sprinter        8148  2026-02-26            8400058
# 1           NS  Sprinter        8148  2026-02-26            8400059
# 2           NS  Sprinter        8148  2026-02-26            8400561
# 3           NS  Sprinter        8148  2026-02-26            8400079
# 4           NS  Sprinter        8148  2026-02-26            8400332
# ...        ...       ...         ...         ...                ...
# 6623158     HU        Gy           7  2026-03-04            2238100
# 6623159     HU        Gy           7  2026-03-04            5500064
# 6623160     HU        Gy           7  2026-03-04            5500061
# 6623161     HU        Gy           7  2026-03-04            5500053
# 6623162     HU        Gy           7  2026-03-04            5500058
#
#                           timestamp  originalRoute    originalStopId  \
# 0            2026-02-25 04:51:47+00  Sprinter 8148           2992170
# ...

# %%
data.head(5)
# Out:
#   agency routeType routeNumber        date deutscheBahnStopId  \
# 0     NS  Sprinter        8148  2026-02-26            8400058
# 1     NS  Sprinter        8148  2026-02-26            8400059
# 2     NS  Sprinter        8148  2026-02-26            8400561
# 3     NS  Sprinter        8148  2026-02-26            8400079
# 4     NS  Sprinter        8148  2026-02-26            8400332
#
#                 timestamp  originalRoute originalStopId              stopName  \
# 0  2026-02-25 04:51:47+00  Sprinter 8148        2992170    Amsterdam Centraal
# 1  2026-02-25 04:51:47+00  Sprinter 8148        2992236  Amsterdam Sloterdijk
# 2  2026-02-25 04:51:47+00  Sprinter 8148        3065389      Schiphol Airport
# 3  2026-02-25 04:51:47+00  Sprinter 8148        2860888    Amsterdam Lelylaan
# 4  2026-02-25 04:51:47+00  Sprinter 8148        2993022             Hoofddorp
#
#                   arrival  ... arrivalPlatform  plannedArrivalPlatform  \
# ...

# %%
DB = data[data["agency"]=="DB"]
DB.head(5)
# Out:
#      agency routeType routeNumber        date deutscheBahnStopId  \
# 2901     DB        IR        3393  2026-02-26            8504414
# 2902     DB        IR        3393  2026-02-26            8507000
# 2903     DB        IR        3393  2026-02-26            8504300
# 3622     DB        IR        1842  2026-02-26            8501303
# 3623     DB        IR        1842  2026-02-26            8501300
#
#                        timestamp originalRoute originalStopId        stopName  \
# 2901  2026-02-26 00:11:47.283+00       IR 3393        8504414            Lyss
# 2902  2026-02-26 00:11:47.283+00       IR 3393        8507000            Bern
# 2903  2026-02-26 00:11:47.283+00       IR 3393        8504300     Biel/Bienne
# 3622  2026-02-26 00:20:56.635+00       IR 1842        8501303  Villeneuve(CH)
# 3623  2026-02-26 00:20:56.635+00       IR 1842        8501300        Montreux
#
#                      arrival  ... arrivalPlatform  plannedArrivalPlatform  \
# ...

# %%
DB["routeType"].unique()
# Out:
# array(['IR', 'IC', 'RJ', 'ICE', nan, 'BUS', 'D', 'EC', 'RJX', 'S', 'REX',
#        'TGV', 'EST', 'RE', 'EN', 'WB', 'ECE', 'FLX', 'R', 'NJ', 'ES',
#        'UEX'], dtype=object)

# %% [markdown]
# BUS? Is that Flxbus? If so, what is FLX ?
#
# WB = Westbahn I guess
#
#
# Do they have a way to calculate distances? otherwise, depending on our need, might be interesting to integrate Gmaps API
#
#
# Do they have a way to filter for long distances?

# %%
data[data["originalRoute"]=="Sprinter 8148"]
# Out:
#         agency routeType routeNumber        date deutscheBahnStopId  \
# 0           NS  Sprinter        8148  2026-02-26            8400058
# 1           NS  Sprinter        8148  2026-02-26            8400059
# 2           NS  Sprinter        8148  2026-02-26            8400561
# 3           NS  Sprinter        8148  2026-02-26            8400079
# 4           NS  Sprinter        8148  2026-02-26            8400332
# 3848630     NS  Sprinter        8148  2026-03-02            8400561
# 3848634     NS  Sprinter        8148  2026-03-02            8400332
# 3849443     NS  Sprinter        8148  2026-03-02            8400059
# 3849446     NS  Sprinter        8148  2026-03-02            8400058
# 3849450     NS  Sprinter        8148  2026-03-02            8400079
# 5021303     NS  Sprinter        8148  2026-03-03            8400561
# 5021304     NS  Sprinter        8148  2026-03-03            8400332
# 5021305     NS  Sprinter        8148  2026-03-03            8400079
# ...

# %%
data[(data["originalRoute"]=="Sprinter 8148") & (data["date"]=="2026-02-26")]
# Out:
#   agency routeType routeNumber        date deutscheBahnStopId  \
# 0     NS  Sprinter        8148  2026-02-26            8400058
# 1     NS  Sprinter        8148  2026-02-26            8400059
# 2     NS  Sprinter        8148  2026-02-26            8400561
# 3     NS  Sprinter        8148  2026-02-26            8400079
# 4     NS  Sprinter        8148  2026-02-26            8400332
#
#                 timestamp  originalRoute originalStopId              stopName  \
# 0  2026-02-25 04:51:47+00  Sprinter 8148        2992170    Amsterdam Centraal
# 1  2026-02-25 04:51:47+00  Sprinter 8148        2992236  Amsterdam Sloterdijk
# 2  2026-02-25 04:51:47+00  Sprinter 8148        3065389      Schiphol Airport
# 3  2026-02-25 04:51:47+00  Sprinter 8148        2860888    Amsterdam Lelylaan
# 4  2026-02-25 04:51:47+00  Sprinter 8148        2993022             Hoofddorp
#
#                   arrival  ... arrivalPlatform  plannedArrivalPlatform  \
# ...

# %%
data["deutscheBahnStopId"].describe()
# Out:
# count     6623163
# unique      33063
# top       8011162
# freq         9767
# Name: deutscheBahnStopId, dtype: object

# %%
data["deutscheBahnStopId"].isna().sum()
# Out:
# np.int64(0)

# %%
data["deutscheBahnStopId"].unique()
# Out:
# array(['8400058', '8400059', '8400561', ..., 646550, 8005920, '57208_2_1'],
#       dtype=object)

# %%
print(len(data.columns))
print(data.columns)
# Out:
# 22
# Index(['agency', 'routeType', 'routeNumber', 'date', 'deutscheBahnStopId',
#        'timestamp', 'originalRoute', 'originalStopId', 'stopName', 'arrival',
#        'plannedArrival', 'arrivalDelay', 'arrivalPlatform',
#        'plannedArrivalPlatform', 'arrivalCancelled', 'departure',
#        'plannedDeparture', 'departureDelay', 'departurePlatform',
#        'plannedDeparturePlatform', 'departureCancelled', 'extra'],
#       dtype='object')
